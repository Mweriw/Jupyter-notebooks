# %%
#Elvis Mweri
#BCSC01/0017/2018
#supervised learning
#DecisionTree Algorithm
import pandas as pd
#importing the excel dataset
df=pd.read_excel("Persons_Gender_Height_Weight_Index data.xlsx")
df
# Out:
#     Gender  Height  Weight
# 0     Male     174      96
# 1     Male     189      87
# 2   Female     185     110
# 3   Female     195     104
# 4     Male     149      61
# 5     Male     189     104
# 6     Male     147      92
# 7     Male     154     111
# 8     Male     174      90
# 9   Female     169     103
# 10    Male     195      81
# 11  Female     159      80
# 12  Female     192     101
# 13    Male     155      51
# 14    Male     191      79
# 15  Female     153     107
# 16  Female     157     110
# 17    Male     140     129
# 18    Male     144     145
# 19    Male     172     139
# 20    Male     157     110
# 21  Female     153     149
# 22  Female     169      97
# 23    Male     185     139
# 24  Female     172      67
# 25  Female     151      64
# 26    Male     190      95
# 27    Male     187      62
# 28  Female     163     159

# %%
#shape of the data
df.shape
# Out:
# (29, 3)

# %%
#basic statistics
df.describe()
# Out:
#            Height      Weight
# count   29.000000   29.000000
# mean   169.310345  100.758621
# std     17.462416   27.788301
# min    140.000000   51.000000
# 25%    154.000000   81.000000
# 50%    169.000000  101.000000
# 75%    187.000000  110.000000
# max    195.000000  159.000000

# %%
df.tail()
# Out:
#     Gender  Height  Weight
# 24  Female     172      67
# 25  Female     151      64
# 26    Male     190      95
# 27    Male     187      62
# 28  Female     163     159

# %%
df.head()
# Out:
#    Gender  Height  Weight
# 0    Male     174      96
# 1    Male     189      87
# 2  Female     185     110
# 3  Female     195     104
# 4    Male     149      61

# %%
#representing gender string with integers
Gender={'Male':1, 'Female':0}
df.Gender=[Gender[item] for item in df.Gender]
df
# Out:
#     Gender  Height  Weight
# 0        1     174      96
# 1        1     189      87
# 2        0     185     110
# 3        0     195     104
# 4        1     149      61
# 5        1     189     104
# 6        1     147      92
# 7        1     154     111
# 8        1     174      90
# 9        0     169     103
# 10       1     195      81
# 11       0     159      80
# 12       0     192     101
# 13       1     155      51
# 14       1     191      79
# 15       0     153     107
# 16       0     157     110
# 17       1     140     129
# 18       1     144     145
# 19       1     172     139
# 20       1     157     110
# 21       0     153     149
# 22       0     169      97
# 23       1     185     139
# 24       0     172      67
# 25       0     151      64
# 26       1     190      95
# 27       1     187      62
# 28       0     163     159

# %%
#preparation of data
x=df.drop(columns=['Weight'])
y=df['Weight']
x
# Out:
#     Gender  Height
# 0        1     174
# 1        1     189
# 2        0     185
# 3        0     195
# 4        1     149
# 5        1     189
# 6        1     147
# 7        1     154
# 8        1     174
# 9        0     169
# 10       1     195
# 11       0     159
# 12       0     192
# 13       1     155
# 14       1     191
# 15       0     153
# 16       0     157
# 17       1     140
# 18       1     144
# 19       1     172
# 20       1     157
# 21       0     153
# 22       0     169
# 23       1     185
# 24       0     172
# 25       0     151
# 26       1     190
# 27       1     187
# 28       0     163

# %%
#learning and predicting
from sklearn.tree import DecisionTreeClassifier
model= DecisionTreeClassifier()
model.fit(x,y)
prediction=model.predict([ [180,1],[170,1] ])
prediction
# Out:
# C:\Users\aa\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# array([129, 129], dtype=int64)

# %%
#supervised learning
#logistic regression Algorithm
from matplotlib import pyplot as plt
z=plt.scatter(df.Height,df.Weight)
z

# %%
#training the model
from sklearn.model_selection import train_test_split
train_test_split(df[['Height']],df.Weight, train_size=0.6)
# Out:
# [    Height
#  3      195
#  10     195
#  7      154
#  4      149
#  24     172
#  27     187
#  28     163
#  20     157
#  12     192
#  16     157
#  1      189
#  5      189
#  21     153
#  19     172
#  2      185
#  11     159
#  15     153,
#      Height
#  22     169
#  8      174
#  17     140
#  18     144
#  14     191
#  25     151
#  9      169
#  26     190
#  0      174
#  6      147
#  23     185
#  13     155,
#  3     104
#  10     81
#  7     111
#  4      61
#  24     67
#  27     62
#  28    159
#  20    110
#  12    101
#  16    110
#  1      87
#  5     104
#  21    149
#  19    139
#  2     110
#  11     80
#  15    107
#  Name: Weight, dtype: int64,
#  22     97
#  8      90
#  17    129
#  18    145
#  14     79
#  25     64
#  9     103
#  26     95
#  0      96
#  6      92
#  23    139
#  13     51
#  Name: Weight, dtype: int64]

# %%
x_train,x_test,y_train,y_test=train_test_split(df[['Height']],df.Weight, test_size=0.4)

# %%
x_test
# Out:
#     Height
# 21     153
# 25     151
# 17     140
# 28     163
# 23     185
# 13     155
# 5      189
# 4      149
# 14     191
# 26     190
# 2      185
# 6      147

# %%
x_train
# Out:
#     Height
# 1      189
# 8      174
# 11     159
# 3      195
# 9      169
# 22     169
# 24     172
# 10     195
# 20     157
# 18     144
# 7      154
# 27     187
# 0      174
# 19     172
# 16     157
# 12     192
# 15     153

# %%
#import the logistic regression module
from sklearn.linear_model import LogisticRegression

# %%
model=LogisticRegression()

# %%
#training the model
model.fit(x_train,y_train)
# Out:
# C:\Users\aa\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
model.predict(x_test)
# Out:
# array([107, 107, 145, 110,  62, 110,  87, 145, 101,  87,  62, 145],
#       dtype=int64)
